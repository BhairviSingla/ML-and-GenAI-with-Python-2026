# %%
print("Bhairvi Singla")
# Out:
# Bhairvi Singla

# %%
print("Bhairvi Singla \nIGDTUW \nPatiala")
print("Hi my name is Bhairvi, I study in IGDTUW")
# Out:
# Bhairvi Singla
# IGDTUW
# Patiala
# Hi my name is Bhairvi, I study in IGDTUW

# %%
for i in range (5):
  print (i)
# Out:
# 0
# 1
# 2
# 3
# 4

# %%
x=5
if x>0:
  print("yes")
else:
  print("no")
# Out:
# yes

# %%
if False:
  #single comment
  print("Python")

# %%
name,roll,course,marks="Rahul",23,"DS",60
print(name ,"\n", marks, "\n", course, "\n", marks )
# Out:
# Rahul
#  60
#  DS
#  60

# %%
PI=3.14
area=3*3*PI
print(area)
# Out:
# 28.26

# %%
#list, ordered, mutable
numbers=[10,70,30,40]
print(numbers)
#tuple, ordered, immutable
colors=("red","orange","yellow")
print(colors)
#sets, unique values
x={1,2,3,3,4,5,6,6}
print(x)
#dictionary key-value pairs
students={
    "name": "Rahul",
    "marks": 94,
}
print(students)

print(type(numbers), "\n", type(colors), "\n", type(x), "\n", type(students))
# Out:
# [10, 70, 30, 40]
# ('red', 'orange', 'yellow')
# {1, 2, 3, 4, 5, 6}
# {'name': 'Rahul', 'marks': 94}
# <class 'list'>
#  <class 'tuple'>
#  <class 'set'>
#  <class 'dict'>

# %%
name= input("enter name:")
print("hello", name)
marks=int(input("Enter marks:"))
print("Your marks are", marks)
# Out:
# enter name:Bhairvi
# hello Bhairvi
# Enter marks:90
# Your marks are 90

# %% [markdown]
# ASSIGNMENT CLASS 1

# %%
l=4
b=6
print(l*b)
# Out:
# 24

# %%
principle,rate,time=1000,2,2
si=(principle*rate*time)/100
print(si)
# Out:
# 40.0

# %%
celsius=0
fahrenheit=(9/5)*celsius+32
print(fahrenheit)
# Out:
# 32.0

# %%
a,b,c=10,20,30
average=(a+b+c)/3
print(average)
# Out:
# 20.0

# %%
number=2
sq=number*number
cube=number*number*number
print("Square is:",sq,"\nCube is:",cube)
# Out:
# Square is: 4
# Cube is: 8

# %%
a,b=3,4
a=a-b
b=a+b
a=b-a
print("a is:",a,"\nb is:",b)
# Out:
# a is: 4
# b is: 3

# %%
name=input("Enter Student Name:")
roll=input("Enter Student Roll:")
marks=[0,0,0]
for i in range(3):
  marks[i]=int(input("Enter subject's marks:"))
print(name)
print(roll)
for i in range (3):
  print(marks[i])
# Out:
# Enter Student Name:Bhairvi
# Enter Student Roll:12
# Enter subject's marks:10
# Enter subject's marks:20
# Enter subject's marks:30
# Bhairvi
# 12
# 10
# 20
# 30
